# %% [markdown]
# <a href="https://colab.research.google.com/github/Naren152/Naren/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import the neccessary modules
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Read the dataset into a dataframe
df = pd.read_csv("/content/human_vital_signs_dataset_2024.csv")

# %%
df.drop(columns=['Timestamp'], inplace=True)

# %%
df.drop(columns=['Gender'], inplace=True)

# %%
df.shape
# Out:
# (200020, 15)

# %%
df.head()
# Out:
#    Patient ID  Heart Rate  Respiratory Rate  Body Temperature  \
# 0           1          60                12         36.861707
# 1           2          63                18         36.511633
# 2           3          63                15         37.052049
# 3           4          99                16         36.654748
# 4           5          69                16         36.975098
#
#    Oxygen Saturation  Systolic Blood Pressure  Diastolic Blood Pressure  Age  \
# 0          95.702046                      124                        86   37
# 1          96.689413                      126                        84   77
# 2          98.508265                      131                        78   68
# 3          95.011801                      118                        72   41
# 4          98.623792                      138                        76   25
#
#    Weight (kg)  Height (m)  Derived_HRV  Derived_Pulse_Pressure  Derived_BMI  \
# ...

# %%
df.describe()
# Out:
#           Patient ID     Heart Rate  Respiratory Rate  Body Temperature  \
# count  200020.000000  200020.000000     200020.000000     200020.000000
# mean   100010.500000      79.533747         15.489451         36.748353
# std     57740.944759      11.552894          2.294472          0.433290
# min         1.000000      60.000000         12.000000         36.000004
# 25%     50005.750000      70.000000         13.000000         36.372613
# 50%    100010.500000      80.000000         15.000000         36.747741
# 75%    150015.250000      90.000000         17.000000         37.123003
# max    200020.000000      99.000000         19.000000         37.499992
#
#        Oxygen Saturation  Systolic Blood Pressure  Diastolic Blood Pressure  \
# count      200020.000000            200020.000000             200020.000000
# mean           97.504372               124.437971                 79.499625
# std             1.442598                 8.656946                  5.757248
# ...

# %%
df.isnull()
# Out:
#         Patient ID  Heart Rate  Respiratory Rate  Body Temperature  \
# 0            False       False             False             False
# 1            False       False             False             False
# 2            False       False             False             False
# 3            False       False             False             False
# 4            False       False             False             False
# ...            ...         ...               ...               ...
# 200015       False       False             False             False
# 200016       False       False             False             False
# 200017       False       False             False             False
# 200018       False       False             False             False
# 200019       False       False             False             False
#
#         Oxygen Saturation  Systolic Blood Pressure  Diastolic Blood Pressure  \
# 0                   False                    False                     False
# ...

# %%
df.isnull().sum()
# Out:
# Patient ID                  0
# Heart Rate                  0
# Respiratory Rate            0
# Body Temperature            0
# Oxygen Saturation           0
# Systolic Blood Pressure     0
# Diastolic Blood Pressure    0
# Age                         0
# Weight (kg)                 0
# Height (m)                  0
# Derived_HRV                 0
# Derived_Pulse_Pressure      0
# Derived_BMI                 0
# Derived_MAP                 0
# Risk Category               0
# dtype: int64

# %%
df["Risk Category"].value_counts()
# Out:
# Risk Category
# High Risk    105115
# Low Risk      94905
# Name: count, dtype: int64

# %%
sns.countplot(df["Risk Category"])
plt.xlabel("Risk Category")
plt.ylabel("Count")
plt.title("Risk Category Count Plot")
plt.show()

# %%
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# %%
X.shape
# Out:
# (200020, 14)

# %%
y.shape
# Out:
# (200020,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=99)

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(criterion = "gini",
                             max_depth = 8,
                             min_samples_split = 10,
                             random_state= 5)

# %%
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=8, min_samples_split=10, random_state=5)

# %%
clf.feature_importances_
# Out:
# array([3.12365159e-04, 3.30510653e-01, 7.44103295e-05, 3.18223807e-04,
#        3.69848560e-04, 1.17137047e-04, 1.26785402e-04, 1.79193699e-04,
#        9.84320324e-02, 6.46192303e-02, 3.75680063e-04, 1.86921607e-04,
#        5.04220943e-01, 1.56575103e-04])

# %%
y_pred = clf.predict(X_test)

# %%
y_pred
# Out:
# array(['High Risk', 'High Risk', 'Low Risk', ..., 'High Risk',
#        'High Risk', 'High Risk'], dtype=object)

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, y_pred)
# Out:
# array([[21137,     0],
#        [    0, 18867]])

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 1.0

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#    High Risk       1.00      1.00      1.00     21137
#     Low Risk       1.00      1.00      1.00     18867
#
#     accuracy                           1.00     40004
#    macro avg       1.00      1.00      1.00     40004
# weighted avg       1.00      1.00      1.00     40004

# %%
features = df.columns
importances = clf.feature_importances_
indices = np.argsort(importances)

plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices], color='b', align='center')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Relative Importance')
plt.show()
